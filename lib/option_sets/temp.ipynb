# %%
import pandas as pd
import json

with open('navigation_help_info.json', 'r', encoding='utf-8') as file:
  data = json.load(file)
df = pd.DataFrame(data)
df
# Out:
#                                               icon
# 0                                    mdi:file-sign  \
# 1                            fa6-regular:handshake
# 2   material-symbols:order-approve-outline-rounded
# 3                          fluent:money-24-regular
# 4                                          ion:pin
# 5                      fluent-mdl2:product-variant
# 6                                mdi:people-switch
# 7                                         ph:globe
# 8                                clarity:tag-solid
# 9                                          fa:tags
# 10                               mdi:calendar-star
# 11                    mdi:calendar-refresh-outline
# 12                iconamoon:certificate-badge-fill
# 13                              solar:user-id-bold
# 14                            codicon:organization
# 15                                 mdi:account-cog
# 16                   iconoir:network-reverse-solid
# ...

# %%
df.to_json("data.json", orient="records", indent=4)
